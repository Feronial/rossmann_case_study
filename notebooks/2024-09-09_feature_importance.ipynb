# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/processed/rossmann_sales_df.csv')  # Replace 'your_data.csv' with your file name
df = df.drop('Date', axis=1)
df.head()
# Out:
#    Store  DayOfWeek  Sales  Customers  Open  Promo  SchoolHoliday  Day  Month  \
# 0      1          4   4709        571     1      0              0   31      1
# 1      1          5   5681        630     1      1              0    8      2
# 2      1          6   5370        656     1      0              0    9      2
# 3      1          7      0          0     0      0              0   10      2
# 4      1          1   4409        599     1      0              0   11      2
#
#    Quarter  ...  MedianSales_LastWeek  MinSales_LastWeek  MaxSales_LastWeek  \
# 0        1  ...                4601.0                0.0             5598.0
# 1        1  ...                5970.0                0.0             7032.0
# 2        1  ...                5970.0                0.0             7032.0
# 3        1  ...                5681.0                0.0             7032.0
# 4        1  ...                5681.0                0.0             7032.0
#
#    StdSales_LastWeek  TotalCustomers_LastWeek  MeanCustomers_LastWeek  \
# 0        1951.681400                   3592.0              513.142857
# 1        2340.568592                   4167.0              595.285714
# 2        2342.155946                   4139.0              591.285714
# 3        2319.977258                   4094.0              584.857143
# 4        2319.977258                   4094.0              584.857143
#
#    MedianCustomers_LastWeek  MinCustomers_LastWeek  MaxCustomers_LastWeek  \
# 0                     560.0                    0.0                  676.0
# 1                     678.0                    0.0                  762.0
# 2                     678.0                    0.0                  762.0
# 3                     675.0                    0.0                  762.0
# 4                     675.0                    0.0                  762.0
#
#    StdCustomers_LastWeek
# 0             233.408389
# 1             264.578731
# 2             263.682710
# 3             261.097956
# 4             261.097956
#
# [5 rows x 52 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 882294 entries, 0 to 882293
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Store                      882294 non-null  int64
#  1   DayOfWeek                  882294 non-null  int64
#  2   Sales                      882294 non-null  int64
#  3   Customers                  882294 non-null  int64
#  4   Open                       882294 non-null  int64
#  5   Promo                      882294 non-null  int64
#  6   SchoolHoliday              882294 non-null  int64
#  7   Day                        882294 non-null  int64
#  8   Month                      882294 non-null  int64
#  9   Quarter                    882294 non-null  int64
#  10  CompetitionDistance        882294 non-null  float64
#  11  CompetitionOpenSinceMonth  882294 non-null  float64
#  12  CompetitionOpenSinceYear   882294 non-null  float64
#  13  Promo2                     882294 non-null  int64
#  14  Promo2SinceWeek            882294 non-null  float64
#  15  Promo2SinceYear            882294 non-null  float64
#  16  StateHoliday_0             882294 non-null  int64
#  17  StateHoliday_a             882294 non-null  int64
#  18  StateHoliday_b             882294 non-null  int64
#  19  StateHoliday_c             882294 non-null  int64
#  20  StoreType_a                882294 non-null  int64
#  21  StoreType_b                882294 non-null  int64
#  22  StoreType_c                882294 non-null  int64
#  23  StoreType_d                882294 non-null  int64
#  24  PromoInterval_Jan          882294 non-null  int64
#  25  PromoInterval_Feb          882294 non-null  int64
#  26  PromoInterval_Mar          882294 non-null  int64
#  27  PromoInterval_Apr          882294 non-null  int64
#  28  PromoInterval_May          882294 non-null  int64
#  29  PromoInterval_Jun          882294 non-null  int64
#  30  PromoInterval_Jul          882294 non-null  int64
#  31  PromoInterval_Aug          882294 non-null  int64
#  32  PromoInterval_Sept         882294 non-null  int64
#  33  PromoInterval_Oct          882294 non-null  int64
#  34  PromoInterval_Nov          882294 non-null  int64
#  35  PromoInterval_Dec          882294 non-null  int64
#  36  Sales_LastWeek             882294 non-null  float64
#  37  Sales_LastMonth            882294 non-null  float64
#  38  Customers_LastWeek         882294 non-null  float64
#  39  Customers_LastMonth        882294 non-null  float64
#  40  TotalSales_LastWeek        882294 non-null  float64
#  41  MeanSales_LastWeek         882294 non-null  float64
#  42  MedianSales_LastWeek       882294 non-null  float64
#  43  MinSales_LastWeek          882294 non-null  float64
#  44  MaxSales_LastWeek          882294 non-null  float64
#  45  StdSales_LastWeek          882294 non-null  float64
#  46  TotalCustomers_LastWeek    882294 non-null  float64
#  47  MeanCustomers_LastWeek     882294 non-null  float64
#  48  MedianCustomers_LastWeek   882294 non-null  float64
#  49  MinCustomers_LastWeek      882294 non-null  float64
#  50  MaxCustomers_LastWeek      882294 non-null  float64
#  51  StdCustomers_LastWeek      882294 non-null  float64
# dtypes: float64(21), int64(31)
# memory usage: 350.0 MB

# %%
# Select numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Downcast int64 to int32 and float64 to float32
df[numerical_cols] = df[numerical_cols].astype({col: 'int32' if df[col].dtype == 'int64' else 'float32' for col in numerical_cols})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 882294 entries, 0 to 882293
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Store                      882294 non-null  int32
#  1   DayOfWeek                  882294 non-null  int32
#  2   Sales                      882294 non-null  int32
#  3   Customers                  882294 non-null  int32
#  4   Open                       882294 non-null  int32
#  5   Promo                      882294 non-null  int32
#  6   SchoolHoliday              882294 non-null  int32
#  7   Day                        882294 non-null  int32
#  8   Month                      882294 non-null  int32
#  9   Quarter                    882294 non-null  int32
#  10  CompetitionDistance        882294 non-null  float32
#  11  CompetitionOpenSinceMonth  882294 non-null  float32
#  12  CompetitionOpenSinceYear   882294 non-null  float32
#  13  Promo2                     882294 non-null  int32
#  14  Promo2SinceWeek            882294 non-null  float32
#  15  Promo2SinceYear            882294 non-null  float32
#  16  StateHoliday_0             882294 non-null  int32
#  17  StateHoliday_a             882294 non-null  int32
#  18  StateHoliday_b             882294 non-null  int32
#  19  StateHoliday_c             882294 non-null  int32
#  20  StoreType_a                882294 non-null  int32
#  21  StoreType_b                882294 non-null  int32
#  22  StoreType_c                882294 non-null  int32
#  23  StoreType_d                882294 non-null  int32
#  24  PromoInterval_Jan          882294 non-null  int32
#  25  PromoInterval_Feb          882294 non-null  int32
#  26  PromoInterval_Mar          882294 non-null  int32
#  27  PromoInterval_Apr          882294 non-null  int32
#  28  PromoInterval_May          882294 non-null  int32
#  29  PromoInterval_Jun          882294 non-null  int32
#  30  PromoInterval_Jul          882294 non-null  int32
#  31  PromoInterval_Aug          882294 non-null  int32
#  32  PromoInterval_Sept         882294 non-null  int32
#  33  PromoInterval_Oct          882294 non-null  int32
#  34  PromoInterval_Nov          882294 non-null  int32
#  35  PromoInterval_Dec          882294 non-null  int32
#  36  Sales_LastWeek             882294 non-null  float32
#  37  Sales_LastMonth            882294 non-null  float32
#  38  Customers_LastWeek         882294 non-null  float32
#  39  Customers_LastMonth        882294 non-null  float32
#  40  TotalSales_LastWeek        882294 non-null  float32
#  41  MeanSales_LastWeek         882294 non-null  float32
#  42  MedianSales_LastWeek       882294 non-null  float32
#  43  MinSales_LastWeek          882294 non-null  float32
#  44  MaxSales_LastWeek          882294 non-null  float32
#  45  StdSales_LastWeek          882294 non-null  float32
#  46  TotalCustomers_LastWeek    882294 non-null  float32
#  47  MeanCustomers_LastWeek     882294 non-null  float32
#  48  MedianCustomers_LastWeek   882294 non-null  float32
#  49  MinCustomers_LastWeek      882294 non-null  float32
#  50  MaxCustomers_LastWeek      882294 non-null  float32
#  51  StdCustomers_LastWeek      882294 non-null  float32
# dtypes: float32(21), int32(31)
# memory usage: 175.0 MB

# %%
# Select relevant features
target = 'Sales'


# Split data into features (X) and target (y)
X = df.drop(target, axis=1)
y = df[target]

X, _, y, _ = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
# Train a Random Forest model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X, y)

# Get feature importances
feature_importances = rf_model.feature_importances_

# Create a DataFrame to visualize feature importances
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Train a Logistic Regression model
lr_model = LogisticRegression(max_iter=1000, random_state=42)
lr_model.fit(X, y)

# Get coefficients (feature importance for Logistic Regression)
coefficients = lr_model.coef_[0]

# Create a DataFrame to visualize feature importances
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': coefficients})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance (Logistic Regression)')
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from sklearn.inspection import permutation_importance

# Calculate permutation importance
result = permutation_importance(
    rf_model, X, y, n_repeats=10, random_state=42
)

# Get feature importances
perm_importance = result.importances_mean

# Create a DataFrame to visualize permutation importance
perm_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': perm_importance})
perm_importance_df = perm_importance_df.sort_values(by='Importance', ascending=False)

# Plot permutation importance
plt.figure(figsize=(10, 6))
plt.barh(perm_importance_df['Feature'], perm_importance_df['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Permutation Importance')
plt.show()
